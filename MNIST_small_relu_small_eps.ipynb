# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
from datetime import datetime as dt
from copy import deepcopy
import torch
print(torch.__version__)
print(torch.cuda.is_available())

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as f

import torchvision
from torchvision.datasets import MNIST
from torchvision.transforms import transforms

from torch.utils.data import DataLoader

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from attacks import fgsm, pgd
from model import SmallIntervalNet
from layers import *
# Out:
# 1.7.0
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def copy_model(Model, old):
    new_model = Model().to(device)
    for layer, old_layer in zip(new_model.children(), old.children()):
        print(layer)
        layer.weight.data = old_layer.weight.data.clone()
    return new_model

def pgd(model, X, y, loss_fn, epsilon=0.1, alpha=0.01, num_iter=20):
    delta = torch.zeros_like(X, requires_grad=True)
    for t in range(num_iter):
        loss = loss_fn(model(X + delta), y)
        loss.backward()
        delta.data = (delta + alpha*delta.grad.detach().sign()).clamp(-epsilon,epsilon)
        delta.data = torch.min(torch.max(delta.detach(), -X), 1-X) # clip X+delta to [0,1]
        delta.grad.zero_()
    return delta.detach()


from datetime import datetime as dt

def clean_acc(model, loader):
    clean_correct = 0.
    model.eval()
    with torch.no_grad():
        for k, (X, y) in enumerate(loader, 1):
            start = dt.now().replace(microsecond=0)
            X, y = X.to(device), y.to(device)  
            clean_correct += (model(X).argmax(dim=1) == y).sum().item()
            end = dt.now().replace(microsecond=0)
            print(f"iter: {k}/{len(loader)} time: {end-start}", end="\r")
        print(" " * 50, end="\r")
        acc = round(clean_correct / len(loader.dataset), 4)
        print(f"clean accuracy: {acc}")
    return acc

def adv_acc(model, loader, loss_fn, attack, attack_params):
    model.eval()
    adv_correct = [0] * len(attack_params)
    for i, (name, params) in enumerate(attack_params):
        for k, (X, y) in enumerate(loader, 1):
            start = dt.now().replace(microsecond=0)
            X, y = X.to(device), y.to(device)
            noise = attack(model, X, y, loss_fn, **params)
            out = model(X+noise)
            adv_correct[i] += (out.argmax(dim=1) == y).sum().item()
            end = dt.now().replace(microsecond=0)
            print(f"iter: {k}/{len(loader)} time: {end-start}", end="\r")
        print(" " * 50, end="\r")
        print(f"name: {name} accuracy: {(adv_correct[i] / len(loader.dataset)):.4f}")
    return [round(a/len(loader.dataset), 4) for a in adv_correct]


def print_table(models, attacks, clean, adv):
    d = {'model': models, 'clean image': clean}
    for i, (name, p) in enumerate(attacks):
        d[name] = [adv[j][i] for j, _ in enumerate(adv)]

    return pd.DataFrame(data=d)

# %%
seed = torch.seed()
print(f"seed: {seed}")
torch.manual_seed(seed)
# Out:
# seed: 4596606540121938325

# %%
import re
import os
from datetime import datetime as dt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt

class Trainer:

    def __init__(self, model_name, train_dataset, test_dataset, batch_size=(200, 200)):
        self.batch_size = batch_size
        self.train_dl = DataLoader(train_dataset, batch_size=batch_size[0], shuffle=True)
        self.test_dl = DataLoader(test_dataset, batch_size=batch_size[1], shuffle=True)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(self.device)
        self.logs = {}
        self.eps, self.kappa = 0.005, 1
        self.interval_train = False
        self.model_name = model_name
        self.checkpoint_path = "saved/{}/{}_{}_checkpoint.pt"
        os.makedirs(f"saved/{model_name}/", exist_ok=True)

    def _interval_based_bound(self, model, c, bounds, idx):
        # requires last layer to be linear
        cW = c.t() @ (model.last_layer.weight - self.eps)
        cb = c.t() @ model.last_layer.bias
        l, u = bounds
        return (cW.clamp(min=0) @ l[idx].t() + cW.clamp(max=0) @ u[idx].t() + cb[:, None]).t()


    def _train_test_epoch(self, model, loader, loss_fn, optimizer=None):
        C = [-torch.eye(10).to(self.device) for _ in range(10)]
        for y0 in range(10):
            C[y0][y0, :] += 1

        robust_err = 0
        total_loss, accuracy = 0., 0.
        for k, (X, y) in enumerate(loader, 1):
            start = dt.now().replace(microsecond=0)
            X, y = X.to(self.device), y.to(self.device)
            if optimizer is None:
                out = model(X)
            else:
                out = model(torch.cat([X, X], dim=1))
            fit_loss = self.kappa * loss_fn(out, y)
            accuracy += (out.argmax(dim=1) == y).sum().item()

            robust_loss = 0
            for y0 in range(10):
                if sum(y == y0) > 0:
                    lower_bound = self._interval_based_bound(model, C[y0], model.bounds, y == y0)
                    robust_loss += nn.CrossEntropyLoss(reduction='sum')(-lower_bound, y[y == y0]) / X.shape[0]

                    # increment when true label is not winning
                    robust_err += (lower_bound.min(dim=1)[0] < 0).sum().item()

            # combined losss
            combined_loss = self.kappa * fit_loss + (1 - self.kappa) * robust_loss

            if optimizer is not None:
                optimizer.zero_grad()
                combined_loss.backward()
                optimizer.step()
                
#                 if self.eps < 0.1:
#                     self.eps += 0.000008333
#                     model.set_eps(self.eps)

                if self.kappa > 0.5:
                    self.kappa -= 0.000020833
                else:
                    self.kappa = 0.5

            total_loss += combined_loss.data.item() * X.size(0)
            end = dt.now().replace(microsecond=0)
            print(f"{self.phase_name} iteration: {k}/{len(loader)} time: {end - start}", end="\r")

            
        print(" " * 80, end="\r")

        return total_loss/len(loader.dataset), accuracy/len(loader.dataset), robust_err/len(loader.dataset)

    def _train(self, model, loss_fn, optimizer):
        model.train()
        self.phase_name = "train"
        with torch.enable_grad():
            return self._train_test_epoch(model, self.train_dl, loss_fn, optimizer)

    def _test(self, model, loss_fn):
        model.eval()
        self.phase_name = "test"
        with torch.no_grad():
            return self._train_test_epoch(model, self.test_dl, loss_fn)

    def train(self, model, loss_fn, optimizer, scheduler=None, epochs=30, patience=4):
        self.logs = {
            'loss': {"train": [], "test": []},
            'accuracy': {"train": [], "test": []},
            'robust error': {"train": [], "test": []},
        }
        model = model.to(self.device)
        epochs_no_improve, min_loss = np.inf, float('inf')
        min_robust_err = float('inf')

        for e in range(1, epochs+1):
            if e > 1:
                model.set_eps(0.005)
                self.eps = 0.005
            else:
                model.set_eps(0)
                self.eps=0
            start = dt.now().replace(microsecond=0)
            print(f"epoch start with: eps: {self.eps:.8f}, kappa: {self.kappa:.8f}")
            train_loss, train_acc, train_err = self._train(model, loss_fn, optimizer)
            test_loss, test_acc, test_err = self._test(model, loss_fn)
            followed_metric = test_loss
            if scheduler is not None:
                scheduler.step(followed_metric)
            end = dt.now().replace(microsecond=0)
            out = "Epoch: {} Validation Loss: {:.4f} accuracy: {:.4f}, robust err: {:.4f}, time: {}"
            print(out.format(e, test_loss, test_acc, test_err, end - start), end="\n\n")

            # Update logs
            self.logs['loss']["train"].append(train_loss)
            self.logs['loss']["test"].append(test_loss)
            self.logs['accuracy']["train"].append(train_acc)
            self.logs['accuracy']["test"].append(test_acc)
            self.logs['robust error']["train"].append(train_err)
            self.logs['robust error']["test"].append(test_err)

            torch.save(model.state_dict(), self.checkpoint_path.format(self.model_name, self.model_name, str(e)))

        return self.logs


def plot_history(model_name, hists):
    x = np.arange(1, len(hists["loss"]["test"]) + 1)
    f, axes = plt.subplots(nrows=1, ncols=len(hists), figsize=(15, 5))
    for ax, (name, hist) in zip(axes, hists.items()):
        for label, h in hist.items():
            ax.plot(x, h, label=label)

        ax.set_title("Model " + name)
        ax.set_xlabel('epochs')
        ax.set_ylabel(name)
        ax.legend(loc="best")

    f.savefig(f"{model_name}.png", dpi=f.dpi)
    plt.show()

# %%
tr_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor()
])
vl_transform = transforms.Compose([
    transforms.ToTensor()
])

ds_train = MNIST('../data', train=True, download=True, transform=tr_transform)
ds_test = MNIST('../data', train=False, download=True, transform=vl_transform)

# %%
from interval_layers import LinearInterval, Conv2dInterval

class Small(nn.Module):

    def __init__(self, eps=0):
        super().__init__()
        self.conv1 = Conv2dInterval(1, 16, 4, 2, eps=eps)
        self.conv2 = Conv2dInterval(16, 32, 4, 1, eps=eps)
        self.fc1 = LinearInterval(32*10*10, 100, eps=eps)
        self.last_layer = LinearInterval(100, 10, eps=eps)

        self.bounds = None

    def forward(self, x):
        x = f.relu(self.conv1(x))
        x = f.relu(self.conv2(x))
        x = torch.flatten(x, 1)
        x = f.relu(self.fc1(x))
        if self.training:
            self.bounds = x[:, :x.size(1)// 2], x[:, x.size(1)//2:]
        x = self.last_layer(x)
        return ((x[:, :x.size(1)// 2] + x[:, x.size(1)//2:])/2) if self.training else x

    def bounds(self):
        return self.bounds
    
    def set_eps(self, eps):
        for layer in self.children():
            layer.eps = eps

# %%
model_name = "mnist_small_relu_small_eps"

trainer = Trainer(model_name, ds_train, ds_test, batch_size=(100, 100))
model = Small(eps=0.005)
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', min_lr=1e-4,
                                                 patience=2, verbose=True)

history = trainer.train(model, loss_fn, optimizer, scheduler, epochs=100, patience=6)
plot_history(model_name, history)
torch.save(model.state_dict(), f"saved/{model_name}/{model_name}_final.pt")
# Out:
# cuda
# epoch start with: eps: 0.00000000, kappa: 1.00000000
# Epoch: 1 Validation Loss: 0.2705 accuracy: 0.9549, robust err: 0.8941, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.98750020
# Epoch: 2 Validation Loss: 2.2667 accuracy: 0.3710, robust err: 1.0000, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.97500040
# Epoch: 3 Validation Loss: 2.5319 accuracy: 0.3214, robust err: 1.0000, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.96250060
# Epoch     4: reducing learning rate of group 0 to 1.0000e-04.
# Epoch: 4 Validation Loss: 2.7384 accuracy: 0.3819, robust err: 0.9911, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.95000080
# Epoch: 5 Validation Loss: 2.9844 accuracy: 0.3793, robust err: 0.9856, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.93750100
# Epoch: 6 Validation Loss: 3.2559 accuracy: 0.4000, robust err: 0.9909, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.92500120
# Epoch: 7 Validation Loss: 3.4603 accuracy: 0.4106, robust err: 0.9782, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.91250140
# Epoch: 8 Validation Loss: 3.9137 accuracy: 0.4028, robust err: 0.9777, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.90000160
# Epoch: 9 Validation Loss: 4.0463 accuracy: 0.4120, robust err: 0.9779, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.88750180
# Epoch: 10 Validation Loss: 4.4395 accuracy: 0.4231, robust err: 0.9702, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.87500200
# Epoch: 11 Validation Loss: 4.7068 accuracy: 0.4347, robust err: 0.9816, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.86250220
# Epoch: 12 Validation Loss: 4.9315 accuracy: 0.4363, robust err: 0.9722, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.85000240
# Epoch: 13 Validation Loss: 5.1978 accuracy: 0.4431, robust err: 0.9808, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.83750260
# Epoch: 14 Validation Loss: 5.6556 accuracy: 0.4496, robust err: 0.9660, time: 0:01:12
#
# epoch start with: eps: 0.00500000, kappa: 0.82500280
# Epoch: 15 Validation Loss: 6.0487 accuracy: 0.4621, robust err: 0.9763, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.81250300
# Epoch: 16 Validation Loss: 6.4155 accuracy: 0.4596, robust err: 0.9672, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.80000320
# Epoch: 17 Validation Loss: 7.1892 accuracy: 0.4777, robust err: 0.9765, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.78750340
# Epoch: 18 Validation Loss: 7.4409 accuracy: 0.4791, robust err: 0.9668, time: 0:01:12
#
# epoch start with: eps: 0.00500000, kappa: 0.77500360
# Epoch: 19 Validation Loss: 8.1471 accuracy: 0.4848, robust err: 0.9722, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.76250380
# Epoch: 20 Validation Loss: 8.1787 accuracy: 0.4996, robust err: 0.9743, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.75000400
# Epoch: 21 Validation Loss: 7.8560 accuracy: 0.5301, robust err: 0.9701, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.73750420
# Epoch: 22 Validation Loss: 10.1325 accuracy: 0.5730, robust err: 0.9668, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.72500440
# Epoch: 23 Validation Loss: 9.6269 accuracy: 0.5989, robust err: 0.9730, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.71250460
# Epoch: 24 Validation Loss: 10.4926 accuracy: 0.6063, robust err: 0.9670, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.70000480
# Epoch: 25 Validation Loss: 11.2708 accuracy: 0.6549, robust err: 0.9517, time: 0:01:12
#
# epoch start with: eps: 0.00500000, kappa: 0.68750500
# Epoch: 26 Validation Loss: 12.1448 accuracy: 0.6948, robust err: 0.9543, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.67500520
# Epoch: 27 Validation Loss: 12.3030 accuracy: 0.7153, robust err: 0.9394, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.66250540
# Epoch: 28 Validation Loss: 12.3959 accuracy: 0.7439, robust err: 0.9387, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.65000560
# Epoch: 29 Validation Loss: 12.8638 accuracy: 0.7613, robust err: 0.9466, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.63750580
# Epoch: 30 Validation Loss: 12.5835 accuracy: 0.7713, robust err: 0.9478, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.62500600
# Epoch: 31 Validation Loss: 13.5383 accuracy: 0.7890, robust err: 0.9323, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.61250620
# Epoch: 32 Validation Loss: 13.8115 accuracy: 0.7926, robust err: 0.9302, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.60000640
# Epoch: 33 Validation Loss: 14.9810 accuracy: 0.8064, robust err: 0.9288, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.58750660
# Epoch: 34 Validation Loss: 14.8102 accuracy: 0.8892, robust err: 0.9337, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.57500680
# Epoch: 35 Validation Loss: 15.2154 accuracy: 0.9028, robust err: 0.9319, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.56250700
# Epoch: 36 Validation Loss: 14.1265 accuracy: 0.9105, robust err: 0.9357, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.55000720
# Epoch: 37 Validation Loss: 15.2763 accuracy: 0.9185, robust err: 0.9216, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.53750740
# Epoch: 38 Validation Loss: 16.1987 accuracy: 0.9266, robust err: 0.9207, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.52500760
# Epoch: 39 Validation Loss: 17.3368 accuracy: 0.9312, robust err: 0.9137, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.51250780
# Epoch: 40 Validation Loss: 16.6177 accuracy: 0.9343, robust err: 0.9189, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000800
# Epoch: 41 Validation Loss: 17.0891 accuracy: 0.9354, robust err: 0.9063, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 42 Validation Loss: 17.1303 accuracy: 0.9395, robust err: 0.9208, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 43 Validation Loss: 17.0325 accuracy: 0.9401, robust err: 0.9229, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 44 Validation Loss: 16.6950 accuracy: 0.9440, robust err: 0.9142, time: 0:01:04
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 45 Validation Loss: 17.4080 accuracy: 0.9465, robust err: 0.9154, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 46 Validation Loss: 18.1736 accuracy: 0.9492, robust err: 0.9109, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 47 Validation Loss: 19.0308 accuracy: 0.9514, robust err: 0.9072, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 48 Validation Loss: 18.4510 accuracy: 0.9533, robust err: 0.9133, time: 0:01:04
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 49 Validation Loss: 18.7582 accuracy: 0.9535, robust err: 0.9159, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 50 Validation Loss: 19.1169 accuracy: 0.9552, robust err: 0.9049, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 51 Validation Loss: 18.8280 accuracy: 0.9570, robust err: 0.9109, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 52 Validation Loss: 19.9748 accuracy: 0.9579, robust err: 0.9132, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 53 Validation Loss: 20.0377 accuracy: 0.9593, robust err: 0.9106, time: 0:01:11
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 54 Validation Loss: 20.0737 accuracy: 0.9606, robust err: 0.9107, time: 0:01:04
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 55 Validation Loss: 19.3775 accuracy: 0.9611, robust err: 0.9128, time: 0:01:04
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 56 Validation Loss: 19.3317 accuracy: 0.9620, robust err: 0.9139, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 57 Validation Loss: 21.1958 accuracy: 0.9627, robust err: 0.9134, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 58 Validation Loss: 21.0816 accuracy: 0.9648, robust err: 0.9054, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 59 Validation Loss: 21.1216 accuracy: 0.9649, robust err: 0.9015, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 60 Validation Loss: 20.9255 accuracy: 0.9663, robust err: 0.9104, time: 0:01:11
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 61 Validation Loss: 22.0022 accuracy: 0.9662, robust err: 0.9182, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 62 Validation Loss: 21.9662 accuracy: 0.9663, robust err: 0.9105, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 63 Validation Loss: 24.3344 accuracy: 0.9668, robust err: 0.9014, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 64 Validation Loss: 23.1247 accuracy: 0.9670, robust err: 0.9153, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 65 Validation Loss: 23.8600 accuracy: 0.9679, robust err: 0.9127, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 66 Validation Loss: 23.9986 accuracy: 0.9687, robust err: 0.9067, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 67 Validation Loss: 22.8811 accuracy: 0.9690, robust err: 0.9125, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 68 Validation Loss: 25.0816 accuracy: 0.9693, robust err: 0.9100, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 69 Validation Loss: 24.5295 accuracy: 0.9694, robust err: 0.9046, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 70 Validation Loss: 23.8694 accuracy: 0.9706, robust err: 0.9165, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 71 Validation Loss: 26.0170 accuracy: 0.9705, robust err: 0.9135, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 72 Validation Loss: 27.5192 accuracy: 0.9702, robust err: 0.9106, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 73 Validation Loss: 27.2375 accuracy: 0.9706, robust err: 0.9010, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 74 Validation Loss: 28.2216 accuracy: 0.9709, robust err: 0.9091, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 75 Validation Loss: 27.0309 accuracy: 0.9713, robust err: 0.9102, time: 0:01:12
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 76 Validation Loss: 28.2438 accuracy: 0.9720, robust err: 0.9023, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 77 Validation Loss: 28.8849 accuracy: 0.9717, robust err: 0.9078, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 78 Validation Loss: 29.4256 accuracy: 0.9722, robust err: 0.9155, time: 0:00:59
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 79 Validation Loss: 28.4304 accuracy: 0.9719, robust err: 0.9069, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 80 Validation Loss: 29.4141 accuracy: 0.9711, robust err: 0.9048, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 81 Validation Loss: 30.3072 accuracy: 0.9729, robust err: 0.9036, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 82 Validation Loss: 31.4822 accuracy: 0.9721, robust err: 0.9131, time: 0:01:11
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 83 Validation Loss: 32.1447 accuracy: 0.9730, robust err: 0.9063, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 84 Validation Loss: 30.8903 accuracy: 0.9735, robust err: 0.9009, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 85 Validation Loss: 29.8389 accuracy: 0.9742, robust err: 0.9088, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 86 Validation Loss: 33.0050 accuracy: 0.9736, robust err: 0.9077, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 87 Validation Loss: 33.7239 accuracy: 0.9740, robust err: 0.9051, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 88 Validation Loss: 34.4510 accuracy: 0.9746, robust err: 0.8984, time: 0:01:11
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 89 Validation Loss: 36.6226 accuracy: 0.9750, robust err: 0.9070, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 90 Validation Loss: 32.0515 accuracy: 0.9750, robust err: 0.9037, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 91 Validation Loss: 33.4794 accuracy: 0.9751, robust err: 0.9099, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 92 Validation Loss: 34.4533 accuracy: 0.9753, robust err: 0.9097, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 93 Validation Loss: 36.0076 accuracy: 0.9751, robust err: 0.8977, time: 0:01:11
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 94 Validation Loss: 33.4197 accuracy: 0.9761, robust err: 0.9045, time: 0:01:10
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 95 Validation Loss: 37.0825 accuracy: 0.9753, robust err: 0.9040, time: 0:01:07
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 96 Validation Loss: 36.5011 accuracy: 0.9768, robust err: 0.9002, time: 0:01:09
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 97 Validation Loss: 39.7693 accuracy: 0.9760, robust err: 0.8965, time: 0:01:05
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 98 Validation Loss: 39.7695 accuracy: 0.9765, robust err: 0.9076, time: 0:01:06
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 99 Validation Loss: 39.5131 accuracy: 0.9761, robust err: 0.9075, time: 0:01:08
#
# epoch start with: eps: 0.00500000, kappa: 0.50000000
# Epoch: 100 Validation Loss: 38.0198 accuracy: 0.9769, robust err: 0.9049, time: 0:01:08

# %%
test_transform = transforms.Compose([
    transforms.ToTensor(),
])

ds = MNIST('../data', train=False, target_transform=None, download=True, transform=test_transform)
test_loader = DataLoader(ds, 200, shuffle=True)


def create_attack(eps, alpha, num_iter):
    d = {
        "epsilon": eps,
        "alpha": alpha,
        "num_iter": num_iter
    }
    return f"e={eps:.1f},a={alpha:.1f},i={num_iter}", d
    

attack1 = create_attack(eps=0.1, alpha=0.1, num_iter=30)
attack2 = create_attack(eps=0.2, alpha=0.1, num_iter=30)
attack3 = create_attack(eps=0.3, alpha=0.1, num_iter=30)
attack4 = create_attack(eps=0.4, alpha=0.1, num_iter=30)

params = [attack1, attack2, attack3, attack4]

# %%
model_name = "mnist_small_relu_small_eps"

# %%
clean, adv = [], []

model = Small().to(device)
model.load_state_dict(torch.load(f"saved/{model_name}/{model_name}_5_checkpoint.pt", map_location=device))

acc = clean_acc(model, test_loader)
acc_adv = adv_acc(model, test_loader, nn.CrossEntropyLoss(), pgd, params)

clean.append(acc)
adv.append(acc_adv)
# Out:
# clean accuracy: 0.3793
# name: e=0.1,a=0.1,i=30 accuracy: 0.1782
# name: e=0.2,a=0.1,i=30 accuracy: 0.0963
# name: e=0.3,a=0.1,i=30 accuracy: 0.0922
# name: e=0.4,a=0.1,i=30 accuracy: 0.0919

# %%
clean, adv = [], []

model = Small().to(device)
model.load_state_dict(torch.load(f"saved/{model_name}/{model_name}_10_checkpoint.pt", map_location=device))

acc = clean_acc(model, test_loader)
acc_adv = adv_acc(model, test_loader, nn.CrossEntropyLoss(), pgd, params)

clean.append(acc)
adv.append(acc_adv)
# Out:
# clean accuracy: 0.4231
# name: e=0.1,a=0.1,i=30 accuracy: 0.2768
# name: e=0.2,a=0.1,i=30 accuracy: 0.1110
# name: e=0.3,a=0.1,i=30 accuracy: 0.1049
# name: e=0.4,a=0.1,i=30 accuracy: 0.1043

# %%
clean, adv = [], []

model = Small().to(device)
model.load_state_dict(torch.load(f"saved/{model_name}/{model_name}_40_checkpoint.pt", map_location=device))

acc = clean_acc(model, test_loader)
acc_adv = adv_acc(model, test_loader, nn.CrossEntropyLoss(), pgd, params)

clean.append(acc)
adv.append(acc_adv)
# Out:
# clean accuracy: 0.9343
# name: e=0.1,a=0.1,i=30 accuracy: 0.7129
# name: e=0.2,a=0.1,i=30 accuracy: 0.0424
# name: e=0.3,a=0.1,i=30 accuracy: 0.0052
# name: e=0.4,a=0.1,i=30 accuracy: 0.0044

# %%
clean, adv = [], []

model = Small().to(device)
model.load_state_dict(torch.load(f"saved/{model_name}/{model_name}_50_checkpoint.pt", map_location=device))

acc = clean_acc(model, test_loader)
acc_adv = adv_acc(model, test_loader, nn.CrossEntropyLoss(), pgd, params)

clean.append(acc)
adv.append(acc_adv)
# Out:
# clean accuracy: 0.9552
# name: e=0.1,a=0.1,i=30 accuracy: 0.7343
# name: e=0.2,a=0.1,i=30 accuracy: 0.0378
# name: e=0.3,a=0.1,i=30 accuracy: 0.0078
# name: e=0.4,a=0.1,i=30 accuracy: 0.0061

# %%
clean, adv = [], []

model = Small().to(device)
model.load_state_dict(torch.load(f"saved/{model_name}/{model_name}_100_checkpoint.pt", map_location=device))

acc = clean_acc(model, test_loader)
acc_adv = adv_acc(model, test_loader, nn.CrossEntropyLoss(), pgd, params)

clean.append(acc)
adv.append(acc_adv)
# Out:
# clean accuracy: 0.9769
# name: e=0.1,a=0.1,i=30 accuracy: 0.7842
# name: e=0.2,a=0.1,i=30 accuracy: 0.0599
# name: e=0.3,a=0.1,i=30 accuracy: 0.0157
# name: e=0.4,a=0.1,i=30 accuracy: 0.0085
